# %%
# MobileNetV2는 구글이 2018년에 발표한 모바일 및 임베디드 기기용 경량 합성곱 신경망(CNN) 아키텍처
# 컴퓨터 비전 작업을 모바일 기기처럼 연산 능력이 제한된 환경에서 실시간으로 처리할 수 있도록 설계
# 사전 훈련된 MobileNet V2 모델의 기본 라벨(Label) 데이터는 어떤 목적으로 모델을 사용하는지(태스크 및 데이터셋)에 따라 달라짐

# 기본 MobileNetV2 신경망은 ImageNet 데이터셋으로 사전 학습 됨
# 클래스 수: 총 1,000개의 객체 카테고리로 구성

# 학습된 대형 모델(백본)인 MobilenNet v2 그대로 cifar10 dataset 분류하기

# %%
import tensorflow as tf

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()


# 전처리
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.



NUM_CLASSES = 10
# one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train, NUM_CLASSES)
y_test = tf.keras.utils.to_categorical(y_test, NUM_CLASSES)

print('train data : ', x_train.shape)
print('test data : ', x_test.shape)

# %%
# MobileNet v2 모델 불러오기
mobilenet_model = tf.keras.applications.MobileNetV2(
    input_shape=(32, 32, 3),
    classes=NUM_CLASSES,  # cifar10의 클래스 수로 지정
    weights=None,     # 모델 구조만 불러오고 모든 가중치는 랜덤 처리
    include_top=True  # 기본 분류기 포함
)

# %%
mobilenet_model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = mobilenet_model.fit(x_train, y_train, epochs=10, batch_size=64, validation_split=0.2, verbose=2)
